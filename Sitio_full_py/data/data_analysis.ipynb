# %%
import pandas as pd
import os

file_name = "iris.csv"
# casa
# direction = "C:/Users/Casa/PSW/Python/App_Py_FullStack/Sitio_full_py/data"

# laptop
direction = "C:/Users/Laptop/SWF/Python/App_Py_FullStack/Sitio_full_py/data"
fullpath = os.path.join(direction, file_name)

data_frame = pd.read_csv(fullpath)

# data_frame.columns.values
data_frame
# Out:
#      150    4  setosa  versicolor  virginica
# 0    5.1  3.5     1.4         0.2          0
# 1    4.9  3.0     1.4         0.2          0
# 2    4.7  3.2     1.3         0.2          0
# 3    4.6  3.1     1.5         0.2          0
# 4    5.0  3.6     1.4         0.2          0
# ..   ...  ...     ...         ...        ...
# 145  6.7  3.0     5.2         2.3          2
# 146  6.3  2.5     5.0         1.9          2
# 147  6.5  3.0     5.2         2.0          2
# 148  6.2  3.4     5.4         2.3          2
# 149  5.9  3.0     5.1         1.8          2
#
# [150 rows x 5 columns]

# %%
# Lo que da como resultado una lista de listas por columnas
# new_list = data_frame.to_numpy().transpose().tolist()

# Convertir un Dataframe en una lista por filas
new_list_df = data_frame.to_numpy().tolist()

# for i in new_list:
#     print (new_list[i])

# len(new_list)

new_list_df
# Out:
# [[5.1, 3.5, 1.4, 0.2, 0.0],
#  [4.9, 3.0, 1.4, 0.2, 0.0],
#  [4.7, 3.2, 1.3, 0.2, 0.0],
#  [4.6, 3.1, 1.5, 0.2, 0.0],
#  [5.0, 3.6, 1.4, 0.2, 0.0],
#  [5.4, 3.9, 1.7, 0.4, 0.0],
#  [4.6, 3.4, 1.4, 0.3, 0.0],
#  [5.0, 3.4, 1.5, 0.2, 0.0],
#  [4.4, 2.9, 1.4, 0.2, 0.0],
#  [4.9, 3.1, 1.5, 0.1, 0.0],
#  [5.4, 3.7, 1.5, 0.2, 0.0],
#  [4.8, 3.4, 1.6, 0.2, 0.0],
#  [4.8, 3.0, 1.4, 0.1, 0.0],
#  [4.3, 3.0, 1.1, 0.1, 0.0],
#  [5.8, 4.0, 1.2, 0.2, 0.0],
#  [5.7, 4.4, 1.5, 0.4, 0.0],
#  [5.4, 3.9, 1.3, 0.4, 0.0],
#  [5.1, 3.5, 1.4, 0.3, 0.0],
#  [5.7, 3.8, 1.7, 0.3, 0.0],
#  [5.1, 3.8, 1.5, 0.3, 0.0],
#  [5.4, 3.4, 1.7, 0.2, 0.0],
#  [5.1, 3.7, 1.5, 0.4, 0.0],
#  [4.6, 3.6, 1.0, 0.2, 0.0],
#  [5.1, 3.3, 1.7, 0.5, 0.0],
#  [4.8, 3.4, 1.9, 0.2, 0.0],
#  [5.0, 3.0, 1.6, 0.2, 0.0],
#  [5.0, 3.4, 1.6, 0.4, 0.0],
#  [5.2, 3.5, 1.5, 0.2, 0.0],
#  [5.2, 3.4, 1.4, 0.2, 0.0],
#  [4.7, 3.2, 1.6, 0.2, 0.0],
#  [4.8, 3.1, 1.6, 0.2, 0.0],
#  [5.4, 3.4, 1.5, 0.4, 0.0],
#  [5.2, 4.1, 1.5, 0.1, 0.0],
# ...

# %%
new_list2 = [
    [5.1, 3.5, 1.4, 0.2, 0.0],
    [4.9, 3.0, 1.4, 0.2, 0.0],
    [4.7, 3.2, 1.3, 0.2, 0.0],
    [4.6, 3.1, 1.5, 0.2, 0.0],
    [5.0, 3.6, 1.4, 0.2, 0.0],
]


ls_dict = []
# test_dict1 = {}

for index in range(100):

    # print (new_list2[index][0])

    diccionario = {
        "width": new_list_df[index][0],
        "length": new_list_df[index][1],
    }

    ls_dict.append(diccionario)

    # valor1 = new_list2[index][0] # ['150'][index]
    # valor2 = new_list2[index][1]

    # test_dict1 ['width'] = valor1
    # test_dict1 ['lenght'] = valor2

    # ls_dict.append(test_dict1)

ls_dict
    



    #     estudiante = {
    #     "nombre": nombres[i],
    #     "edad": edades[i],
    #     "ciudad": ciudades[i]
    # }
    # estudiantes.append(estudiante)
# Out:
# [{'width': 5.1, 'length': 3.5},
#  {'width': 4.9, 'length': 3.0},
#  {'width': 4.7, 'length': 3.2},
#  {'width': 4.6, 'length': 3.1},
#  {'width': 5.0, 'length': 3.6},
#  {'width': 5.4, 'length': 3.9},
#  {'width': 4.6, 'length': 3.4},
#  {'width': 5.0, 'length': 3.4},
#  {'width': 4.4, 'length': 2.9},
#  {'width': 4.9, 'length': 3.1},
#  {'width': 5.4, 'length': 3.7},
#  {'width': 4.8, 'length': 3.4},
#  {'width': 4.8, 'length': 3.0},
#  {'width': 4.3, 'length': 3.0},
#  {'width': 5.8, 'length': 4.0},
#  {'width': 5.7, 'length': 4.4},
#  {'width': 5.4, 'length': 3.9},
#  {'width': 5.1, 'length': 3.5},
#  {'width': 5.7, 'length': 3.8},
#  {'width': 5.1, 'length': 3.8},
#  {'width': 5.4, 'length': 3.4},
#  {'width': 5.1, 'length': 3.7},
#  {'width': 4.6, 'length': 3.6},
#  {'width': 5.1, 'length': 3.3},
#  {'width': 4.8, 'length': 3.4},
#  {'width': 5.0, 'length': 3.0},
#  {'width': 5.0, 'length': 3.4},
#  {'width': 5.2, 'length': 3.5},
#  {'width': 5.2, 'length': 3.4},
# ...

# %%
# Ejemplo de internet

# # Datos de ejemplo
# nombres = ["Juan", "Ana", "Luis"]
# edades = [20, 22, 21]
# ciudades = ["México", "Guadalajara", "Monterrey"]

# # Lista vacía para almacenar los diccionarios
# estudiantes = []

# # Usar un ciclo for para llenar la lista de diccionarios
# for i in range(len(nombres)):
#     estudiante = {
#         "nombre": nombres[i],
#         "edad": edades[i],
#         "ciudad": ciudades[i]
#     }
#     estudiantes.append(estudiante)

# print(estudiantes)

# %%
# Recorriendo las filas con iterrows, oara un dataframe esto no funciona()
# test_dict = {}
# ls_dict = []

# for index, row in data_frame.iterrows():
#     # print(f"Fila: {index}")
#     print(f"150: {row['150']}, 4: {row['4']}, versicolor: {row['versicolor']}")
#     test_dict ['150'] = {row['150']}
#     test_dict ['y'] = row['4']
#     ls_dict.append(test_dict)

# ls_dict

# %%
data01 = [
    {"x": 100, "y": 200, "z": 200},
    {"x": 120, "y": 100, "z": 260},
    {"x": 170, "y": 300, "z": 400},
    {"x": 170, "y": 250, "z": 280},
    {"x": 150, "y": 400, "z": 500},
    {"x": 110, "y": 280, "z": 200},
]

type(data01)

# %%
# Recorrer una columna data_frame, de forma MANUAL
diccionario_5 = {}
lista_5 : list = []
num : int = 40

# valor1 = data_frame.copy(data_frame['150'][0])
# valor2 = data_frame.copy(data_frame['4'][0])

valor1 = data_frame['150'][0].copy()
valor2 = data_frame['4'][0].copy()

# valor1 = data_frame.loc[0, '150']
# valor2 = data_frame.loc[0, '150']

diccionario_5 ['width'] = valor1
diccionario_5 ['lenght'] = valor2

# print (diccionario_5)

lista_5.append(diccionario_5)
print (lista_5)

valor1 = data_frame['150'][1].copy()
valor2 = data_frame['4'][1].copy()

diccionario_5 ['width'] = valor1
diccionario_5 ['lenght'] = valor2

lista_5.append(diccionario_5)
print (lista_5)
# Out:
# [{'width': 5.1, 'lenght': 3.5}]
# [{'width': 4.9, 'lenght': 3.0}, {'width': 4.9, 'lenght': 3.0}]

# %%
# Recorrer una columna data_frame, con un FOR
test_dict = {}
ls_dict = []



for index in range(5): #data_frame['150']:
    test_dict1 = {}
    ls_dict = []

    # print(index)
    # Acceder al primer elemento de la columna 'Edad'
    # elemento = data_frame['150'][index]
    # elemento = data_frame.loc[index, '150']
    # test_dict ['width'] = elemento
    print (data_frame['150'][index])
    valor1 = data_frame['150'][index]
    valor2 = data_frame['4'][index]

    test_dict1 ['width'] = valor1
    test_dict1 ['lenght'] = valor2
    # print(index) 

    # ls_dict [index] = test_dict1

    # ls_dict.append(test_dict1)
    ls_dict.extend(test_dict1)
    

print(ls_dict)
# Out:
# 5.1
# 4.9
# 4.7
# 4.6
# 5.0
# ['width', 'lenght']

# %%
# Pruebas de llenado de lista

lista : list = []
tuple = {'a': 10, 'b': 15}

lista.append(tuple)
# print (lista)

tuple = {'a': 10, 'b': 15}
lista.append(tuple)

# for i in range (4):
#     lista.append(tuple)
        

print (lista)
# Out:
# [{'a': 10, 'b': 15}, {'a': 10, 'b': 15}]

# %%
# Out:
# [{'a': 10, 'b': 15}, {'a': 10, 'b': 15}]
