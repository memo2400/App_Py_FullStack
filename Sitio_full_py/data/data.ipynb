# %%
import pandas as pd
import os

file_name = "iris.csv"
direction = "C:/Users/Casa/PSW/Python/App_Py_FullStack/Sitio_full_py/data"
fullpath = os.path.join(direction, file_name)

data_frame = pd.read_csv(fullpath)

data_frame.columns.values
# Out:
# array(['150', '4', 'setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# Recorriendo las filas con iterrows()
test_dict = {}
ls_dict = []

for index, row in data_frame.iterrows():
    print(f"Fila: {index}")
    print(f"150: {row['150']}, 4: {row['4']}, versicolor: {row['versicolor']}")
    test_dict ['150'] = {row['150']}
    test_dict ['4'] = {row['4']}
    ls_dict.append(test_dict)
# Out:
# Fila: 0
# 150: 5.1, 4: 3.5, versicolor: 0.2
# Fila: 1
# 150: 4.9, 4: 3.0, versicolor: 0.2
# Fila: 2
# 150: 4.7, 4: 3.2, versicolor: 0.2
# Fila: 3
# 150: 4.6, 4: 3.1, versicolor: 0.2
# Fila: 4
# 150: 5.0, 4: 3.6, versicolor: 0.2
# Fila: 5
# 150: 5.4, 4: 3.9, versicolor: 0.4
# Fila: 6
# 150: 4.6, 4: 3.4, versicolor: 0.3
# Fila: 7
# 150: 5.0, 4: 3.4, versicolor: 0.2
# Fila: 8
# 150: 4.4, 4: 2.9, versicolor: 0.2
# Fila: 9
# 150: 4.9, 4: 3.1, versicolor: 0.1
# Fila: 10
# 150: 5.4, 4: 3.7, versicolor: 0.2
# Fila: 11
# 150: 4.8, 4: 3.4, versicolor: 0.2
# Fila: 12
# 150: 4.8, 4: 3.0, versicolor: 0.1
# Fila: 13
# 150: 4.3, 4: 3.0, versicolor: 0.1
# Fila: 14
# 150: 5.8, 4: 4.0, versicolor: 0.2
# Fila: 15
# 150: 5.7, 4: 4.4, versicolor: 0.4
# Fila: 16
# 150: 5.4, 4: 3.9, versicolor: 0.4
# Fila: 17
# 150: 5.1, 4: 3.5, versicolor: 0.3
# Fila: 18
# 150: 5.7, 4: 3.8, versicolor: 0.3
# Fila: 19
# 150: 5.1, 4: 3.8, versicolor: 0.3
# Fila: 20
# 150: 5.4, 4: 3.4, versicolor: 0.2
# Fila: 21
# 150: 5.1, 4: 3.7, versicolor: 0.4
# Fila: 22
# 150: 4.6, 4: 3.6, versicolor: 0.2
# Fila: 23
# 150: 5.1, 4: 3.3, versicolor: 0.5
# Fila: 24
# 150: 4.8, 4: 3.4, versicolor: 0.2
# Fila: 25
# 150: 5.0, 4: 3.0, versicolor: 0.2
# Fila: 26
# 150: 5.0, 4: 3.4, versicolor: 0.4
# Fila: 27
# 150: 5.2, 4: 3.5, versicolor: 0.2
# Fila: 28
# 150: 5.2, 4: 3.4, versicolor: 0.2
# Fila: 29
# 150: 4.7, 4: 3.2, versicolor: 0.2
# Fila: 30
# 150: 4.8, 4: 3.1, versicolor: 0.2
# Fila: 31
# 150: 5.4, 4: 3.4, versicolor: 0.4
# Fila: 32
# 150: 5.2, 4: 4.1, versicolor: 0.1
# Fila: 33
# 150: 5.5, 4: 4.2, versicolor: 0.2
# Fila: 34
# 150: 4.9, 4: 3.1, versicolor: 0.2
# Fila: 35
# 150: 5.0, 4: 3.2, versicolor: 0.2
# Fila: 36
# 150: 5.5, 4: 3.5, versicolor: 0.2
# Fila: 37
# 150: 4.9, 4: 3.6, versicolor: 0.1
# Fila: 38
# 150: 4.4, 4: 3.0, versicolor: 0.2
# Fila: 39
# 150: 5.1, 4: 3.4, versicolor: 0.2
# Fila: 40
# 150: 5.0, 4: 3.5, versicolor: 0.3
# Fila: 41
# 150: 4.5, 4: 2.3, versicolor: 0.3
# Fila: 42
# 150: 4.4, 4: 3.2, versicolor: 0.2
# Fila: 43
# 150: 5.0, 4: 3.5, versicolor: 0.6
# Fila: 44
# 150: 5.1, 4: 3.8, versicolor: 0.4
# Fila: 45
# 150: 4.8, 4: 3.0, versicolor: 0.3
# Fila: 46
# 150: 5.1, 4: 3.8, versicolor: 0.2
# Fila: 47
# 150: 4.6, 4: 3.2, versicolor: 0.2
# Fila: 48
# 150: 5.3, 4: 3.7, versicolor: 0.2
# Fila: 49
# 150: 5.0, 4: 3.3, versicolor: 0.2
# Fila: 50
# 150: 7.0, 4: 3.2, versicolor: 1.4
# Fila: 51
# 150: 6.4, 4: 3.2, versicolor: 1.5
# Fila: 52
# 150: 6.9, 4: 3.1, versicolor: 1.5
# Fila: 53
# 150: 5.5, 4: 2.3, versicolor: 1.3
# Fila: 54
# 150: 6.5, 4: 2.8, versicolor: 1.5
# Fila: 55
# 150: 5.7, 4: 2.8, versicolor: 1.3
# Fila: 56
# 150: 6.3, 4: 3.3, versicolor: 1.6
# Fila: 57
# 150: 4.9, 4: 2.4, versicolor: 1.0
# Fila: 58
# 150: 6.6, 4: 2.9, versicolor: 1.3
# Fila: 59
# 150: 5.2, 4: 2.7, versicolor: 1.4
# Fila: 60
# 150: 5.0, 4: 2.0, versicolor: 1.0
# Fila: 61
# 150: 5.9, 4: 3.0, versicolor: 1.5
# Fila: 62
# 150: 6.0, 4: 2.2, versicolor: 1.0
# Fila: 63
# 150: 6.1, 4: 2.9, versicolor: 1.4
# Fila: 64
# 150: 5.6, 4: 2.9, versicolor: 1.3
# Fila: 65
# 150: 6.7, 4: 3.1, versicolor: 1.4
# Fila: 66
# 150: 5.6, 4: 3.0, versicolor: 1.5
# Fila: 67
# 150: 5.8, 4: 2.7, versicolor: 1.0
# Fila: 68
# 150: 6.2, 4: 2.2, versicolor: 1.5
# Fila: 69
# 150: 5.6, 4: 2.5, versicolor: 1.1
# Fila: 70
# 150: 5.9, 4: 3.2, versicolor: 1.8
# Fila: 71
# 150: 6.1, 4: 2.8, versicolor: 1.3
# Fila: 72
# 150: 6.3, 4: 2.5, versicolor: 1.5
# Fila: 73
# 150: 6.1, 4: 2.8, versicolor: 1.2
# Fila: 74
# 150: 6.4, 4: 2.9, versicolor: 1.3
# Fila: 75
# 150: 6.6, 4: 3.0, versicolor: 1.4
# Fila: 76
# 150: 6.8, 4: 2.8, versicolor: 1.4
# Fila: 77
# 150: 6.7, 4: 3.0, versicolor: 1.7
# Fila: 78
# 150: 6.0, 4: 2.9, versicolor: 1.5
# Fila: 79
# 150: 5.7, 4: 2.6, versicolor: 1.0
# Fila: 80
# 150: 5.5, 4: 2.4, versicolor: 1.1
# Fila: 81
# 150: 5.5, 4: 2.4, versicolor: 1.0
# Fila: 82
# 150: 5.8, 4: 2.7, versicolor: 1.2
# Fila: 83
# 150: 6.0, 4: 2.7, versicolor: 1.6
# Fila: 84
# 150: 5.4, 4: 3.0, versicolor: 1.5
# Fila: 85
# 150: 6.0, 4: 3.4, versicolor: 1.6
# Fila: 86
# 150: 6.7, 4: 3.1, versicolor: 1.5
# Fila: 87
# 150: 6.3, 4: 2.3, versicolor: 1.3
# Fila: 88
# 150: 5.6, 4: 3.0, versicolor: 1.3
# Fila: 89
# 150: 5.5, 4: 2.5, versicolor: 1.3
# Fila: 90
# 150: 5.5, 4: 2.6, versicolor: 1.2
# Fila: 91
# 150: 6.1, 4: 3.0, versicolor: 1.4
# Fila: 92
# 150: 5.8, 4: 2.6, versicolor: 1.2
# Fila: 93
# 150: 5.0, 4: 2.3, versicolor: 1.0
# Fila: 94
# 150: 5.6, 4: 2.7, versicolor: 1.3
# Fila: 95
# 150: 5.7, 4: 3.0, versicolor: 1.2
# Fila: 96
# 150: 5.7, 4: 2.9, versicolor: 1.3
# Fila: 97
# 150: 6.2, 4: 2.9, versicolor: 1.3
# Fila: 98
# 150: 5.1, 4: 2.5, versicolor: 1.1
# Fila: 99
# 150: 5.7, 4: 2.8, versicolor: 1.3
# Fila: 100
# 150: 6.3, 4: 3.3, versicolor: 2.5
# Fila: 101
# 150: 5.8, 4: 2.7, versicolor: 1.9
# Fila: 102
# 150: 7.1, 4: 3.0, versicolor: 2.1
# Fila: 103
# 150: 6.3, 4: 2.9, versicolor: 1.8
# Fila: 104
# 150: 6.5, 4: 3.0, versicolor: 2.2
# Fila: 105
# 150: 7.6, 4: 3.0, versicolor: 2.1
# Fila: 106
# 150: 4.9, 4: 2.5, versicolor: 1.7
# Fila: 107
# 150: 7.3, 4: 2.9, versicolor: 1.8
# Fila: 108
# 150: 6.7, 4: 2.5, versicolor: 1.8
# Fila: 109
# 150: 7.2, 4: 3.6, versicolor: 2.5
# Fila: 110
# 150: 6.5, 4: 3.2, versicolor: 2.0
# Fila: 111
# 150: 6.4, 4: 2.7, versicolor: 1.9
# Fila: 112
# 150: 6.8, 4: 3.0, versicolor: 2.1
# Fila: 113
# 150: 5.7, 4: 2.5, versicolor: 2.0
# Fila: 114
# 150: 5.8, 4: 2.8, versicolor: 2.4
# Fila: 115
# 150: 6.4, 4: 3.2, versicolor: 2.3
# Fila: 116
# 150: 6.5, 4: 3.0, versicolor: 1.8
# Fila: 117
# 150: 7.7, 4: 3.8, versicolor: 2.2
# Fila: 118
# 150: 7.7, 4: 2.6, versicolor: 2.3
# Fila: 119
# 150: 6.0, 4: 2.2, versicolor: 1.5
# Fila: 120
# 150: 6.9, 4: 3.2, versicolor: 2.3
# Fila: 121
# 150: 5.6, 4: 2.8, versicolor: 2.0
# Fila: 122
# 150: 7.7, 4: 2.8, versicolor: 2.0
# Fila: 123
# 150: 6.3, 4: 2.7, versicolor: 1.8
# Fila: 124
# 150: 6.7, 4: 3.3, versicolor: 2.1
# Fila: 125
# 150: 7.2, 4: 3.2, versicolor: 1.8
# Fila: 126
# 150: 6.2, 4: 2.8, versicolor: 1.8
# Fila: 127
# 150: 6.1, 4: 3.0, versicolor: 1.8
# Fila: 128
# 150: 6.4, 4: 2.8, versicolor: 2.1
# Fila: 129
# 150: 7.2, 4: 3.0, versicolor: 1.6
# Fila: 130
# 150: 7.4, 4: 2.8, versicolor: 1.9
# Fila: 131
# 150: 7.9, 4: 3.8, versicolor: 2.0
# Fila: 132
# 150: 6.4, 4: 2.8, versicolor: 2.2
# Fila: 133
# 150: 6.3, 4: 2.8, versicolor: 1.5
# Fila: 134
# 150: 6.1, 4: 2.6, versicolor: 1.4
# Fila: 135
# 150: 7.7, 4: 3.0, versicolor: 2.3
# Fila: 136
# 150: 6.3, 4: 3.4, versicolor: 2.4
# Fila: 137
# 150: 6.4, 4: 3.1, versicolor: 1.8
# Fila: 138
# 150: 6.0, 4: 3.0, versicolor: 1.8
# Fila: 139
# 150: 6.9, 4: 3.1, versicolor: 2.1
# Fila: 140
# 150: 6.7, 4: 3.1, versicolor: 2.4
# Fila: 141
# 150: 6.9, 4: 3.1, versicolor: 2.3
# Fila: 142
# 150: 5.8, 4: 2.7, versicolor: 1.9
# Fila: 143
# 150: 6.8, 4: 3.2, versicolor: 2.3
# Fila: 144
# 150: 6.7, 4: 3.3, versicolor: 2.5
# Fila: 145
# 150: 6.7, 4: 3.0, versicolor: 2.3
# Fila: 146
# 150: 6.3, 4: 2.5, versicolor: 1.9
# Fila: 147
# 150: 6.5, 4: 3.0, versicolor: 2.0
# Fila: 148
# 150: 6.2, 4: 3.4, versicolor: 2.3
# Fila: 149
# 150: 5.9, 4: 3.0, versicolor: 1.8

# %%
ls_dict
# Out:
# [{'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}},
#  {'150': {5.9}, '4': {3.0}}]
